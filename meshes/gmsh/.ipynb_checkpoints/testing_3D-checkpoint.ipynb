# %%
from __future__ import print_function
from dolfin import *
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
! gmsh -3 3D.geo -format msh2
# Out:
# Info    : Running 'gmsh -3 3D.geo -format msh2' [Gmsh 4.6.0, 1 node, max. 1 thread]
# Info    : Started on Fri Jul 17 17:22:39 2020
# Info    : Reading '3D.geo'...
# Warning : More than two degenerated edges in one model face of an OCC model
# Warning : More than two degenerated edges in one model face of an OCC model
# Warning : More than two degenerated edges in one model face of an OCC model
# Warning : More than two degenerated edges in one model face of an OCC model
# Info    : Setting mesh master using transformation
# Info    : Setting curve master 40 - 2
# Info    : Setting curve master 59 - 3
# Info    : Setting curve master 58 - 1
# Info    : Setting mesh master using transformation
# Info    : Setting curve master 32 - 12
# Info    : Setting curve master 44 - 13
# Info    : Setting curve master 38 - 14
# Info    : Setting curve master 40 - 2
# Info    : Setting curve master 17 - 8
# Info    : Setting curve master 42 - 9
# Info    : Setting curve master 43 - 11
# Info    : Setting curve master 26 - 10
# Info    : Setting mesh master using transformation
# Info    : Setting curve master 60 - 48
# Info    : Setting curve master 42 - 9
# Info    : Setting curve master 62 - 49
# Info    : Setting mesh master using transformation
# Info    : Setting curve master 65 - 52
# Info    : Setting curve master 43 - 11
# Info    : Setting curve master 64 - 51
# Info    : Setting mesh master using transformation
# Info    : Setting curve master 44 - 13
# Info    : Setting curve master 68 - 55
# Info    : Setting curve master 67 - 54
# Info    : Setting mesh master using transformation
# Info    : Setting curve master 34 - 5
# Info    : Setting curve master 56 - 4
# Info    : Setting curve master 54 - 1
# Info    : Setting mesh master using transformation
# Info    : Setting curve master 32 - 17
# Info    : Setting curve master 33 - 18
# Info    : Setting curve master 24 - 19
# Info    : Setting curve master 30 - 15
# Info    : Setting curve master 34 - 5
# Info    : Setting curve master 31 - 16
# Info    : Setting curve master 12 - 8
# Info    : Setting curve master 28 - 20
# Info    : Setting mesh master using transformation
# Info    : Setting curve master 53 - 50
# Info    : Setting curve master 28 - 20
# Info    : Setting curve master 52 - 48
# Info    : Setting mesh master using transformation
# Info    : Setting curve master 31 - 16
# Info    : Setting curve master 66 - 57
# Info    : Setting curve master 67 - 58
# Info    : Setting mesh master using transformation
# Info    : Setting curve master 33 - 18
# Info    : Setting curve master 65 - 60
# Info    : Setting curve master 63 - 61
# Info    : Setting mesh master using transformation
# Info    : Setting curve master 50 - 4
# Info    : Setting curve master 49 - 3
# Info    : Setting curve master 21 - 6
# Info    : Setting mesh master using transformation
# Info    : Setting curve master 24 - 30
# Info    : Setting curve master 25 - 37
# Info    : Setting curve master 19 - 15
# Info    : Setting curve master 21 - 6
# Info    : Setting curve master 10 - 14
# Info    : Setting curve master 23 - 35
# Info    : Setting curve master 27 - 39
# Info    : Setting curve master 26 - 38
# Info    : Setting mesh master using transformation
# Info    : Setting curve master 53 - 56
# Info    : Setting curve master 23 - 35
# Info    : Setting curve master 51 - 55
# Info    : Setting mesh master using transformation
# Info    : Setting curve master 61 - 57
# Info    : Setting curve master 62 - 59
# Info    : Setting curve master 27 - 39
# Info    : Setting mesh master using transformation
# Info    : Setting curve master 63 - 66
# Info    : Setting curve master 25 - 37
# Info    : Setting curve master 64 - 68
# Info    : Done reading '3D.geo'
# Info    : Reconstructing periodicity for curve connection 10 - 14
# Info    : Reconstructing periodicity for curve connection 12 - 8
# Info    : Reconstructing periodicity for curve connection 17 - 8
# Info    : Reconstructing periodicity for curve connection 19 - 15
# Info    : Reconstructing periodicity for curve connection 21 - 6
# Info    : Reconstructing periodicity for curve connection 23 - 35
# Info    : Reconstructing periodicity for curve connection 24 - 30
# Info    : Reconstructing periodicity for curve connection 25 - 37
# Info    : Reconstructing periodicity for curve connection 26 - 38
# Info    : Reconstructing periodicity for curve connection 27 - 39
# Info    : Reconstructing periodicity for curve connection 28 - 20
# Info    : Reconstructing periodicity for curve connection 30 - 15
# Info    : Reconstructing periodicity for curve connection 31 - 16
# Info    : Reconstructing periodicity for curve connection 32 - 17
# Info    : Reconstructing periodicity for curve connection 33 - 18
# Info    : Reconstructing periodicity for curve connection 34 - 5
# Info    : Reconstructing periodicity for curve connection 38 - 14
# Info    : Reconstructing periodicity for curve connection 40 - 2
# Info    : Reconstructing periodicity for curve connection 42 - 9
# Info    : Reconstructing periodicity for curve connection 43 - 11
# Info    : Reconstructing periodicity for curve connection 44 - 13
# Info    : Reconstructing periodicity for curve connection 49 - 3
# Info    : Reconstructing periodicity for curve connection 50 - 4
# Info    : Reconstructing periodicity for curve connection 51 - 55
# Info    : Reconstructing periodicity for curve connection 52 - 48
# Info    : Reconstructing periodicity for curve connection 53 - 56
# Info    : Reconstructing periodicity for curve connection 54 - 1
# Info    : Reconstructing periodicity for curve connection 56 - 4
# Info    : Reconstructing periodicity for curve connection 58 - 1
# Info    : Reconstructing periodicity for curve connection 59 - 3
# Info    : Reconstructing periodicity for curve connection 60 - 48
# Info    : Reconstructing periodicity for curve connection 61 - 57
# Info    : Reconstructing periodicity for curve connection 62 - 59
# Info    : Reconstructing periodicity for curve connection 63 - 66
# Info    : Reconstructing periodicity for curve connection 64 - 68
# Info    : Reconstructing periodicity for curve connection 65 - 60
# Info    : Reconstructing periodicity for curve connection 66 - 57
# Info    : Reconstructing periodicity for curve connection 67 - 58
# Info    : Reconstructing periodicity for curve connection 68 - 55
# Info    : Reconstructing periodicity for surface connection 8 - 12
# Info    : Reconstructing periodicity for surface connection 10 - 6
# Info    : Reconstructing periodicity for surface connection 14 - 5
# Info    : Reconstructing periodicity for surface connection 20 - 4
# Info    : Reconstructing periodicity for surface connection 22 - 26
# Info    : Reconstructing periodicity for surface connection 23 - 19
# Info    : Reconstructing periodicity for surface connection 25 - 2
# Info    : Reconstructing periodicity for surface connection 29 - 1
# Info    : Reconstructing periodicity for surface connection 31 - 18
# Info    : Reconstructing periodicity for surface connection 32 - 28
# Info    : Reconstructing periodicity for surface connection 33 - 37
# Info    : Reconstructing periodicity for surface connection 34 - 30
# Info    : Reconstructing periodicity for surface connection 35 - 21
# Info    : Reconstructing periodicity for surface connection 36 - 27
# Info    : Reconstructing periodicity for surface connection 38 - 24
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Circle)
# Info    : [ 10%] Meshing curve 3 (Line)
# Info    : [ 10%] Meshing curve 4 (Line)
# Info    : [ 10%] Meshing curve 5 (Circle)
# Info    : [ 10%] Meshing curve 6 (Circle)
# Info    : [ 20%] Meshing curve 8 (Line)
# Info    : [ 20%] Meshing curve 9 (Circle)
# Info    : [ 20%] Meshing curve 11 (Circle)
# Info    : [ 20%] Meshing curve 12 (Line) as a copy of curve 8
# Info    : [ 20%] Meshing curve 13 (Circle)
# Info    : [ 20%] Meshing curve 14 (Line)
# Info    : [ 30%] Meshing curve 15 (Line)
# Info    : [ 30%] Meshing curve 16 (Circle)
# Info    : [ 30%] Meshing curve 17 (Line) as a copy of curve 8
# Info    : [ 30%] Meshing curve 18 (Circle)
# Info    : [ 30%] Meshing curve 19 (Line) as a copy of curve 15
# Info    : [ 30%] Meshing curve 20 (Circle)
# Info    : [ 30%] Meshing curve 21 (Circle) as a copy of curve 6
# Info    : [ 40%] Meshing curve 28 (Circle) as a copy of curve 20
# Info    : [ 50%] Meshing curve 30 (Line) as a copy of curve 15
# Info    : [ 50%] Meshing curve 31 (Circle) as a copy of curve 16
# Info    : [ 50%] Meshing curve 32 (Line) as a copy of curve 17
# Info    : [ 50%] Meshing curve 33 (Circle) as a copy of curve 18
# Info    : [ 50%] Meshing curve 34 (Circle) as a copy of curve 5
# Info    : [ 50%] Meshing curve 35 (Circle)
# Info    : [ 60%] Meshing curve 37 (Circle)
# Info    : [ 60%] Meshing curve 38 (Line) as a copy of curve 14
# Info    : [ 60%] Meshing curve 39 (Circle)
# Info    : [ 60%] Meshing curve 40 (Circle) as a copy of curve 2
# Info    : [ 70%] Meshing curve 42 (Circle) as a copy of curve 9
# Info    : [ 70%] Meshing curve 43 (Circle) as a copy of curve 11
# Info    : [ 70%] Meshing curve 44 (Circle) as a copy of curve 13
# Info    : [ 70%] Meshing curve 48 (Line)
# Info    : [ 80%] Meshing curve 49 (Line) as a copy of curve 3
# Info    : [ 80%] Meshing curve 50 (Line) as a copy of curve 4
# Info    : [ 80%] Meshing curve 52 (Line) as a copy of curve 48
# Info    : [ 80%] Meshing curve 54 (Line) as a copy of curve 1
# Info    : [ 80%] Meshing curve 55 (Line)
# Info    : [ 90%] Meshing curve 56 (Line) as a copy of curve 4
# Info    : [ 90%] Meshing curve 57 (Line)
# Info    : [ 90%] Meshing curve 58 (Line) as a copy of curve 1
# Info    : [ 90%] Meshing curve 59 (Line) as a copy of curve 3
# Info    : [ 90%] Meshing curve 60 (Line) as a copy of curve 48
# Info    : [ 90%] Meshing curve 61 (Line) as a copy of curve 57
# Info    : [ 90%] Meshing curve 62 (Line) as a copy of curve 59
# Info    : [100%] Meshing curve 65 (Line) as a copy of curve 60
# Info    : [100%] Meshing curve 66 (Line) as a copy of curve 57
# Info    : [100%] Meshing curve 67 (Line) as a copy of curve 58
# Info    : [100%] Meshing curve 68 (Line) as a copy of curve 55
# Info    : [100%] Meshing curve 10 (Line) as a copy of curve 14
# Info    : [100%] Meshing curve 23 (Circle) as a copy of curve 35
# Info    : [100%] Meshing curve 24 (Line) as a copy of curve 30
# Info    : [100%] Meshing curve 25 (Circle) as a copy of curve 37
# Info    : [100%] Meshing curve 26 (Line) as a copy of curve 38
# Info    : [100%] Meshing curve 27 (Circle) as a copy of curve 39
# Info    : [100%] Meshing curve 51 (Line) as a copy of curve 55
# Info    : [100%] Meshing curve 53 (Line) as a copy of curve 56
# Info    : [100%] Meshing curve 63 (Line) as a copy of curve 66
# Info    : [100%] Meshing curve 64 (Line) as a copy of curve 68
# Info    : Done meshing 1D (Wall 0.00413108s, CPU 0.004133s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 3 (Sphere, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 7 (Sphere, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 9 (Sphere, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 10 (Plane) as a copy of surface 6
# Info    : [ 30%] Meshing surface 11 (Sphere, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 12 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 13 (Sphere, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 14 (Plane) as a copy of surface 5
# Info    : [ 40%] Meshing surface 15 (Sphere, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 16 (Sphere, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 17 (Sphere, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 18 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 19 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 20 (Plane) as a copy of surface 4
# Info    : [ 60%] Meshing surface 21 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 23 (Plane) as a copy of surface 19
# Info    : [ 70%] Meshing surface 24 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 25 (Plane) as a copy of surface 2
# Info    : [ 70%] Meshing surface 26 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 27 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 28 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 29 (Plane) as a copy of surface 1
# Info    : [ 80%] Meshing surface 30 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 31 (Plane) as a copy of surface 18
# Info    : [ 90%] Meshing surface 32 (Plane) as a copy of surface 28
# Info    : [ 90%] Meshing surface 34 (Plane) as a copy of surface 30
# Info    : [ 90%] Meshing surface 35 (Plane) as a copy of surface 21
# Info    : [100%] Meshing surface 36 (Plane) as a copy of surface 27
# Info    : [100%] Meshing surface 37 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 38 (Plane) as a copy of surface 24
# Info    : [100%] Meshing surface 8 (Plane) as a copy of surface 12
# Info    : [100%] Meshing surface 22 (Plane) as a copy of surface 26
# Info    : [100%] Meshing surface 33 (Plane) as a copy of surface 37
# Info    : Done meshing 2D (Wall 0.019496s, CPU 0.017117s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 9 volumes with 1 connected component
# Info    : Tetrahedrizing 485 nodes...
# Info    : Done tetrahedrizing 493 nodes (Wall 0.00397611s, CPU 0.001226s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.00824308s, CPU 0.00512s)
# Info    : Found volume 2
# Info    : Found volume 6
# Info    : Found volume 7
# Info    : Found volume 1
# Info    : Found volume 8
# Info    : Found volume 9
# Info    : Found volume 4
# Info    : Found volume 3
# Info    : Found volume 5
# Info    : It. 0 - 0 nodes created - worst tet radius 3.67467 (nodes removed 0 0)
# Info    : 3D refinement terminated (590 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 4 nodes could not be inserted
# Info    :  - 2205 tetrahedra created in 0.0046432 sec. (474887 tets/s)
# Info    : Done meshing 3D (Wall 0.0280371s, CPU 0.01873s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 1
# Info    : Optimization starts (volume = 0.0212398) with worst = 0.0903261 / average = 0.819321:
# Info    : 0.00 < quality < 0.10 :         1 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         0 elements
# Info    : 0.60 < quality < 0.70 :         9 elements
# Info    : 0.70 < quality < 0.80 :        18 elements
# Info    : 0.80 < quality < 0.90 :        29 elements
# Info    : 0.90 < quality < 1.00 :        20 elements
# Info    : 1 edge swaps, 0 node relocations (volume = 0.0212398): worst = 0.631669 / average = 0.829487 (Wall 3.71933e-05s, CPU 1.4e-05s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         0 elements
# Info    : 0.60 < quality < 0.70 :         8 elements
# Info    : 0.70 < quality < 0.80 :        19 elements
# Info    : 0.80 < quality < 0.90 :        29 elements
# Info    : 0.90 < quality < 1.00 :        20 elements
# Info    : Optimizing volume 2
# Info    : Optimization starts (volume = 0.830294) with worst = 0.00515818 / average = 0.75416:
# Info    : 0.00 < quality < 0.10 :         7 elements
# Info    : 0.10 < quality < 0.20 :         9 elements
# Info    : 0.20 < quality < 0.30 :        13 elements
# Info    : 0.30 < quality < 0.40 :        20 elements
# Info    : 0.40 < quality < 0.50 :        41 elements
# Info    : 0.50 < quality < 0.60 :       113 elements
# Info    : 0.60 < quality < 0.70 :       297 elements
# Info    : 0.70 < quality < 0.80 :       379 elements
# Info    : 0.80 < quality < 0.90 :       459 elements
# Info    : 0.90 < quality < 1.00 :       255 elements
# Info    : 29 edge swaps, 0 node relocations (volume = 0.830294): worst = 0.315718 / average = 0.76672 (Wall 0.000380039s, CPU 0.00038s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :        19 elements
# Info    : 0.40 < quality < 0.50 :        37 elements
# Info    : 0.50 < quality < 0.60 :       111 elements
# Info    : 0.60 < quality < 0.70 :       297 elements
# Info    : 0.70 < quality < 0.80 :       380 elements
# Info    : 0.80 < quality < 0.90 :       466 elements
# Info    : 0.90 < quality < 1.00 :       254 elements
# Info    : Optimizing volume 3
# Info    : Optimization starts (volume = 0.0210709) with worst = 0.562342 / average = 0.833691:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         1 elements
# Info    : 0.60 < quality < 0.70 :         7 elements
# Info    : 0.70 < quality < 0.80 :        15 elements
# Info    : 0.80 < quality < 0.90 :        31 elements
# Info    : 0.90 < quality < 1.00 :        18 elements
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         1 elements
# Info    : 0.60 < quality < 0.70 :         7 elements
# Info    : 0.70 < quality < 0.80 :        15 elements
# Info    : 0.80 < quality < 0.90 :        31 elements
# Info    : 0.90 < quality < 1.00 :        18 elements
# Info    : Optimizing volume 4
# Info    : Optimization starts (volume = 0.0212697) with worst = 0.653765 / average = 0.835815:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         0 elements
# Info    : 0.60 < quality < 0.70 :         8 elements
# Info    : 0.70 < quality < 0.80 :        14 elements
# Info    : 0.80 < quality < 0.90 :        39 elements
# Info    : 0.90 < quality < 1.00 :        16 elements
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         0 elements
# Info    : 0.60 < quality < 0.70 :         8 elements
# Info    : 0.70 < quality < 0.80 :        14 elements
# Info    : 0.80 < quality < 0.90 :        39 elements
# Info    : 0.90 < quality < 1.00 :        16 elements
# Info    : Optimizing volume 5
# Info    : Optimization starts (volume = 0.021099) with worst = 0.519972 / average = 0.821011:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         1 elements
# Info    : 0.60 < quality < 0.70 :        12 elements
# Info    : 0.70 < quality < 0.80 :        15 elements
# Info    : 0.80 < quality < 0.90 :        28 elements
# Info    : 0.90 < quality < 1.00 :        18 elements
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         1 elements
# Info    : 0.60 < quality < 0.70 :        12 elements
# Info    : 0.70 < quality < 0.80 :        15 elements
# Info    : 0.80 < quality < 0.90 :        28 elements
# Info    : 0.90 < quality < 1.00 :        18 elements
# Info    : Optimizing volume 6
# Info    : Optimization starts (volume = 0.021255) with worst = 0.0983808 / average = 0.823679:
# Info    : 0.00 < quality < 0.10 :         1 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         0 elements
# Info    : 0.60 < quality < 0.70 :         8 elements
# Info    : 0.70 < quality < 0.80 :        14 elements
# Info    : 0.80 < quality < 0.90 :        42 elements
# Info    : 0.90 < quality < 1.00 :        13 elements
# Info    : 1 edge swaps, 0 node relocations (volume = 0.021255): worst = 0.653765 / average = 0.834221 (Wall 3.00407e-05s, CPU 3e-05s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         0 elements
# Info    : 0.60 < quality < 0.70 :         7 elements
# Info    : 0.70 < quality < 0.80 :        15 elements
# Info    : 0.80 < quality < 0.90 :        42 elements
# Info    : 0.90 < quality < 1.00 :        13 elements
# Info    : Optimizing volume 7
# Info    : Optimization starts (volume = 0.0212514) with worst = 0.653765 / average = 0.828997:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         0 elements
# Info    : 0.60 < quality < 0.70 :         8 elements
# Info    : 0.70 < quality < 0.80 :        19 elements
# Info    : 0.80 < quality < 0.90 :        33 elements
# Info    : 0.90 < quality < 1.00 :        17 elements
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         0 elements
# Info    : 0.60 < quality < 0.70 :         8 elements
# Info    : 0.70 < quality < 0.80 :        19 elements
# Info    : 0.80 < quality < 0.90 :        33 elements
# Info    : 0.90 < quality < 1.00 :        17 elements
# Info    : Optimizing volume 8
# Info    : Optimization starts (volume = 0.0212611) with worst = 0.65195 / average = 0.83535:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         0 elements
# Info    : 0.60 < quality < 0.70 :         8 elements
# Info    : 0.70 < quality < 0.80 :        16 elements
# Info    : 0.80 < quality < 0.90 :        34 elements
# Info    : 0.90 < quality < 1.00 :        19 elements
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         0 elements
# Info    : 0.60 < quality < 0.70 :         8 elements
# Info    : 0.70 < quality < 0.80 :        16 elements
# Info    : 0.80 < quality < 0.90 :        34 elements
# Info    : 0.90 < quality < 1.00 :        19 elements
# Info    : Optimizing volume 9
# Info    : Optimization starts (volume = 0.0212595) with worst = 0.0983808 / average = 0.824676:
# Info    : 0.00 < quality < 0.10 :         1 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         0 elements
# Info    : 0.60 < quality < 0.70 :         9 elements
# Info    : 0.70 < quality < 0.80 :        13 elements
# Info    : 0.80 < quality < 0.90 :        40 elements
# Info    : 0.90 < quality < 1.00 :        14 elements
# Info    : 1 edge swaps, 0 node relocations (volume = 0.0212595): worst = 0.653765 / average = 0.835231 (Wall 2.28882e-05s, CPU 2.4e-05s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         0 elements
# Info    : 0.50 < quality < 0.60 :         0 elements
# Info    : 0.60 < quality < 0.70 :         8 elements
# Info    : 0.70 < quality < 0.80 :        14 elements
# Info    : 0.80 < quality < 0.90 :        40 elements
# Info    : 0.90 < quality < 1.00 :        14 elements
# Info    : Done optimizing mesh (Wall 0.00214791s, CPU 0.001363s)
# Info    : Reconstructing periodicity for curve connection 10 - 14
# Info    : Reconstructing periodicity for curve connection 12 - 8
# Info    : Reconstructing periodicity for curve connection 17 - 8
# Info    : Reconstructing periodicity for curve connection 19 - 15
# Info    : Reconstructing periodicity for curve connection 21 - 6
# Info    : Reconstructing periodicity for curve connection 23 - 35
# Info    : Reconstructing periodicity for curve connection 24 - 30
# Info    : Reconstructing periodicity for curve connection 25 - 37
# Info    : Reconstructing periodicity for curve connection 26 - 38
# Info    : Reconstructing periodicity for curve connection 27 - 39
# Info    : Reconstructing periodicity for curve connection 28 - 20
# Info    : Reconstructing periodicity for curve connection 30 - 15
# Info    : Reconstructing periodicity for curve connection 31 - 16
# Info    : Reconstructing periodicity for curve connection 32 - 17
# Info    : Reconstructing periodicity for curve connection 33 - 18
# Info    : Reconstructing periodicity for curve connection 34 - 5
# Info    : Reconstructing periodicity for curve connection 38 - 14
# Info    : Reconstructing periodicity for curve connection 40 - 2
# Info    : Reconstructing periodicity for curve connection 42 - 9
# Info    : Reconstructing periodicity for curve connection 43 - 11
# Info    : Reconstructing periodicity for curve connection 44 - 13
# Info    : Reconstructing periodicity for curve connection 49 - 3
# Info    : Reconstructing periodicity for curve connection 50 - 4
# Info    : Reconstructing periodicity for curve connection 51 - 55
# Info    : Reconstructing periodicity for curve connection 52 - 48
# Info    : Reconstructing periodicity for curve connection 53 - 56
# Info    : Reconstructing periodicity for curve connection 54 - 1
# Info    : Reconstructing periodicity for curve connection 56 - 4
# Info    : Reconstructing periodicity for curve connection 58 - 1
# Info    : Reconstructing periodicity for curve connection 59 - 3
# Info    : Reconstructing periodicity for curve connection 60 - 48
# Info    : Reconstructing periodicity for curve connection 61 - 57
# Info    : Reconstructing periodicity for curve connection 62 - 59
# Info    : Reconstructing periodicity for curve connection 63 - 66
# Info    : Reconstructing periodicity for curve connection 64 - 68
# Info    : Reconstructing periodicity for curve connection 65 - 60
# Info    : Reconstructing periodicity for curve connection 66 - 57
# Info    : Reconstructing periodicity for curve connection 67 - 58
# Info    : Reconstructing periodicity for curve connection 68 - 55
# Info    : Reconstructing periodicity for surface connection 8 - 12
# Info    : Reconstructing periodicity for surface connection 10 - 6
# Info    : Reconstructing periodicity for surface connection 14 - 5
# Info    : Reconstructing periodicity for surface connection 20 - 4
# Info    : Reconstructing periodicity for surface connection 22 - 26
# Info    : Reconstructing periodicity for surface connection 23 - 19
# Info    : Reconstructing periodicity for surface connection 25 - 2
# Info    : Reconstructing periodicity for surface connection 29 - 1
# Info    : Reconstructing periodicity for surface connection 31 - 18
# Info    : Reconstructing periodicity for surface connection 32 - 28
# Info    : Reconstructing periodicity for surface connection 33 - 37
# Info    : Reconstructing periodicity for surface connection 34 - 30
# Info    : Reconstructing periodicity for surface connection 35 - 21
# Info    : Reconstructing periodicity for surface connection 36 - 27
# Info    : Reconstructing periodicity for surface connection 38 - 24
# Info    : 590 nodes 3443 elements
# Info    : Writing '3D.msh'...
# Info    : Done writing '3D.msh'
# Info    : Stopped on Fri Jul 17 17:22:40 2020 (From start: Wall 0.162042s, CPU 0.279352s)

# %%
! dolfin-convert -i gmsh 3D.msh 3D.xml
# Out:
# Converting from Gmsh format (.msh, .gmsh) to DOLFIN XML format
# Expecting 590 vertices
# Found all vertices
# Expecting 2173 cells
# Found all cells
# Conversion done

# %%
a=1
b=1
c=1
vertices = np.array([[0, 0.,0.],#0
                     [a, 0.,0.],#1
                     [a,0.,c],#2
                     [0.,0.,c],#3
                     [0.,b,c],#4
                     [0.,b,0.],#5
                     [a,b,0.],#6
                     [a,b,c]])#7
vol = a*b*c

# %%
mesh = Mesh("3D.xml")

# %%
subdomains = MeshFunction("size_t", mesh, "3D_physical_region.xml")

# %%
class PeriodicBoundary(SubDomain):
    def __init__(self, vertices, tolerance=DOLFIN_EPS):
        """ vertices stores the coordinates of the 4 unit cell corners"""
        SubDomain.__init__(self, tolerance)
        self.tol = tolerance
        self.vv = vertices
        self.a1 = self.vv[1,:]-self.vv[0,:] # x
        self.a2 = self.vv[5,:]-self.vv[0,:] # y
        self.a3 = self.vv[3,:]-self.vv[0,:] # z
        
    def inside(self, x, on_boundary):
        return bool((near(x[0], self.vv[0,0], self.tol) or #outter boundary
                     near(x[1], self.vv[0,1], self.tol) or #left boundary
                     near(x[2], self.vv[0,2], self.tol)) and #bottom boundary
                     (not(
                     (near(x[0], self.vv[1,0], self.tol) and near(x[1], self.vv[1,1], self.tol) and near(x[2], self.vv[1,2], self.tol)) or #vertice 1 
                     (near(x[0], self.vv[2,0], self.tol) and near(x[1], self.vv[2,1], self.tol) and near(x[2], self.vv[2,2], self.tol)) or #vertice 2
                     (near(x[0], self.vv[3,0], self.tol) and near(x[1], self.vv[3,1], self.tol) and near(x[2], self.vv[3,2], self.tol)) or #vertice 3
                     (near(x[0], self.vv[4,0], self.tol) and near(x[1], self.vv[4,1], self.tol) and near(x[2], self.vv[4,2], self.tol)) or #vertice 4
                     (near(x[0], self.vv[5,0], self.tol) and near(x[1], self.vv[5,1], self.tol) and near(x[2], self.vv[5,2], self.tol)) or #vertice 5
                     (near(x[0], self.vv[6,0], self.tol) and near(x[1], self.vv[6,1], self.tol) and near(x[2], self.vv[6,2], self.tol)) or #vertice 6
                     (near(x[1], self.vv[2,1], self.tol) and near(x[2], self.vv[2,2], self.tol)) or #line 3-2
                     (near(x[0], self.vv[4,0], self.tol) and near(x[2], self.vv[4,2], self.tol)) or #line 3-4
                     (near(x[0], self.vv[2,0], self.tol) and near(x[1], self.vv[2,1], self.tol)) or #line 1-2
                     (near(x[0], self.vv[4,0], self.tol) and near(x[1], self.vv[4,1], self.tol)) or #line 4-5
                     (near(x[0], self.vv[6,0], self.tol) and near(x[2], self.vv[6,2], self.tol)) or #line 1-6
                     (near(x[1], self.vv[6,1], self.tol) and near(x[2], self.vv[6,2], self.tol))    #line 5-6
                      )) and on_boundary)

    def map(self, x, y):
        if (near(x[0], self.vv[7,0], self.tol) and near(x[1], self.vv[7,1], self.tol) and near(x[2], self.vv[7,2], self.tol)):# if x=a,y=b,z=c
            y[0] = x[0] - (self.a1[0]+self.a2[0]+self.a3[0])
            y[1] = x[1] - (self.a1[1]+self.a2[1]+self.a3[1])
            y[2] = x[2] - (self.a1[2]+self.a2[2]+self.a3[2])
        elif near(x[0],self.vv[7,0],self.tol) and near(x[2],self.vv[7,2],self.tol): #if on top-right line 2-7
            y[0] = x[0] - self.a1[0]
            y[1] = x[1]
            y[2] = x[2] - self.a3[2]
        elif near(x[1],self.vv[7,1],self.tol) and near(x[2],self.vv[7,2],self.tol): #if on inside top line 4-7
            y[0] = x[0]
            y[1] = x[1] - self.a2[1]
            y[2] = x[2] - self.a3[2]
        elif near(x[0],self.vv[7,0],self.tol) and near(x[1],self.vv[7,1],self.tol): #if on inside right line 6-7
            y[0] = x[0] - self.a1[0]
            y[1] = x[1] - self.a2[1]
            y[2] = x[2]
        elif near(x[0], self.vv[1,0], self.tol): # if x=a - right surface
            y[0] = x[0] - self.a1[0]
            y[1] = x[1] 
            y[2] = x[2]
        elif near(x[1], self.vv[5,1],self.tol): # if y=b - bottom surface
            y[0] = x[0]
            y[1] = x[1] - self.a2[1]
            y[2] = x[2]
        else: #near(x[2],self.vv[3,2],self.tol): #if z=c - top surface
            y[0] = x[0] - self.a3[0]
            y[1] = x[1] - self.a3[1]
            y[2] = x[2] - self.a3[2]

# %%
def get_C_orthotropic(Exx,Eyy,Ezz,Gxy,Gxz,Gyz,nuxy,nuxz,nuyz,phase):
    '''returns the elasticity tensor for anisotropic orthotropic materials'''
    C_inv = np.array([[1/Exx, -nuxy/Exx, -nuxz/Exx, 0., 0., 0.],
                      [-nuxy/Exx, 1/Eyy, -nuyz/Eyy, 0., 0., 0.],
                      [-nuxz/Exx, -nuyz/Eyy, 1/Ezz, 0., 0., 0.],
                      [0., 0., 0., 1/Gyz, 0., 0.],
                      [0., 0., 0., 0., 1/Gxz, 0.],
                      [0., 0., 0., 0., 0., 1/Gxy]])
    C = np.linalg.inv(C_inv)
    return as_matrix(C)

# %%
def strain(U):
    #return  0.5*(grad(U) + grad(U).T)
    return sym(grad(U))

# %%
def strain_Voigt(epsilon):
    """converts to Voigt format"""
    return as_vector([epsilon[0,0],epsilon[1,1],epsilon[2,2],epsilon[1,2]*2,epsilon[0,2]*2,epsilon[0,1]*2])

# %%
def Voigt_stress(s):
    """converts from Voigt format"""
    return as_tensor([[s[0], s[5], s[4]],
                      [s[5], s[1], s[3]],
                      [s[4], s[3], s[2]]])

# %%
def stress(stress):
    return Voigt_stress(stress)

# %%
def stress_Voigt(U,Applied_Strain,E,nu,phase):
    E = E[phase]
    nu = nu[phase]
    G = E / 2 / (1+nu)
    C = get_C_orthotropic(E,E,E,G,G,G,nu,nu,nu,phase)
    return (dot(C, strain_Voigt(strain(U)+ Applied_Strain)))

# %%
def macro_strain(i):
    '''returns the macroscopic strain for the 3 strain load cases'''
    Eps_Voigt = np.zeros((6,))
    Eps_Voigt[i] = 1
    return np.array([[Eps_Voigt[0], Eps_Voigt[5]/2.,Eps_Voigt[4]/2.], 
                    [Eps_Voigt[5]/2., Eps_Voigt[1], Eps_Voigt[3]/2.],
                    [Eps_Voigt[4]/2., Eps_Voigt[3]/2., Eps_Voigt[2]]])

# %%
def fe_problem(mesh,subdomains,vertices,E,nu,tol = 1e-15):
    dx = Measure('dx', domain=mesh, subdomain_data=subdomains)
    Ve = VectorElement("CG", mesh.ufl_cell(), 3) #displacements
    Re = VectorElement("R", mesh.ufl_cell(), 0) #Lagrange multipliers
    W = FunctionSpace(mesh, MixedElement([Ve, Re]), constrained_domain=PeriodicBoundary(vertices, tolerance=tol))
    V = FunctionSpace(mesh, Ve)
    
    v_,lamb_ = TestFunctions(W)
    dv, dlamb = TrialFunctions(W)
    w = Function(W)
    
    Eps = Constant(((0,0,0),(0,0,0),(0,0,0)))
    F = inner(stress(stress_Voigt(dv, Eps,E,nu,0)), strain(v_))*dx(1) + inner(stress(stress_Voigt(dv, Eps,E,nu,1)), strain(v_))*dx(2)
    
    a, L = lhs(F), rhs(F)
    a += dot(lamb_,dv)*dx + dot(dlamb,v_)*dx
    return dx,w,Eps,F,a,L

# %%
def calculate_moduli(dx,w,Eps,F,a,L):
    C_guess_0 = np.zeros((6, 6))
    C_guess_1 = np.zeros((6,6))
    for (j, case) in enumerate(["Exx","Eyy","Ezz","Eyz","Exz","Exy"]):
        print("Solving {} case...".format(case))
        Eps.assign(Constant(macro_strain(j)))
        solve(a == L, w, [], solver_parameters={"linear_solver": "cg"})
        v, lamb = w.split()
        Stress_0 = np.zeros((6,))
        Stress_1 = np.zeros((6,))
        for k in range(6):
            Stress_0[k] = assemble((stress_Voigt(v,Eps,E,nu,0))[k]*dx(1)) / vol
            Stress_1[k] = assemble((stress_Voigt(v,Eps,E,nu,1))[k]*dx(2)) / vol
        C_guess_0[j, :] = Stress_0
        C_guess_1[j, :] = Stress_1
    C_guess = C_guess_0 + C_guess_1
    return C_guess

# %%
dx = Measure('dx', domain=mesh, subdomain_data=subdomains)

# %%
Volume_fraction = assemble(1*dx(2)) / assemble(1*dx) 
print('Volume fraction =', Volume_fraction)
# Out:
# Volume fraction = 0.16970634288002773

# %%
E = [100,100]
nu = [0.2,0.2]

# %%
dx,w,Eps,F,a,L = fe_problem(mesh,subdomains,vertices,E,nu)

# %%
C_guess = calculate_moduli(dx,w,Eps,F,a,L)
# Out:
# Solving Exx case...
# Solving Eyy case...
# Solving Ezz case...
# Solving Eyz case...
# Solving Exz case...
# Solving Exy case...

# %%
E_an = 100
nu_an = 0.2
print("C \n", C_guess)
C_inv = np.linalg.inv(C_guess)
print("Calculated Exx form C.inverse : ", 1/C_inv[0,0])
print("Divergence Exx = ", (1/C_inv[0,0] - E_an)/E_an)
print("Calculated Eyy form C.inverse: ", 1/C_inv[1,1])
print("Divergence Eyy = ", (1/C_inv[1,1] - E_an)/E_an)
print("Calculated Ezz form C.inverse: ", 1/C_inv[2,2])
print("Gyz =  ", 1/C_inv[3,3])
print("Gxz = ", 1/C_inv[4,4])
print("Gxy = ", 1/C_inv[5,5])
# Out:
# C
#  [[ 1.10879967e+02  2.76424934e+01  2.74524530e+01 -5.19874017e-04
#   -6.30626751e-04  6.36032312e-04]
#  [ 2.76424935e+01  1.10924714e+02  2.74604469e+01 -4.96006314e-04
#   -5.15566993e-05 -1.34305963e-04]
#  [ 2.74524530e+01  2.74604469e+01  1.09971875e+02 -1.64412329e-03
#    4.20294584e-04  8.92032155e-06]
#  [-5.19882616e-04 -4.96011326e-04 -1.64422486e-03  4.14812955e+01
#    3.71442179e-03  5.13118636e-04]
#  [-6.30554290e-04 -5.15158722e-05  4.20558176e-04  3.71444772e-03
#    4.14794723e+01 -1.27312400e-03]
#  [ 6.36024610e-04 -1.34312886e-04  8.89296155e-06  5.13133179e-04
#   -1.27313050e-03  4.16299021e+01]]
# Calculated Exx form C.inverse :  99.87467025761238
# Divergence Exx =  -0.0012532974238762052
# Calculated Eyy form C.inverse:  99.91379926566898
# Divergence Eyy =  -0.0008620073433101539
# Calculated Ezz form C.inverse:  99.08938104861993
# Gyz =   41.4812951665752
# Gxz =  41.479471940246654
# Gxy =  41.629902045113866

# %%
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-a9fc960f600d> in <module>
#       1 y = SpatialCoordinate(mesh)
#       2 plt.figure()
# ----> 3 p = plot(0.5*(dot(Eps, y)+v), mode="displacement", title=case)
#       4 plt.show()
#
# NameError: name 'v' is not defined
